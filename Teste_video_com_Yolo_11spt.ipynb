# %%
# !pip install torch torchvision opencv-python
# !git clone https://github.com/ultralytics/yolov5  # Para YOLOv5
# !pip install -r yolov5/requirements.txt
# Out:
# ...
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# ...

# %%
from ultralytics import YOLO

# %%
modelo = YOLO ('yolo11s.pt')

# %%
modelo.predict('barcos.mp4', show = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/366) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/barcos.mp4: 384x640 3 boats, 102.6ms
# video 1/1 (frame 2/366) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/barcos.mp4: 384x640 2 boats, 88.9ms
# video 1/1 (frame 3/366) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/barcos.mp4: 384x640 2 boats, 83.4ms
# ...

# %%
modelo.predict('barco_2.mp4', show = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/96) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/barco_2.mp4: 640x384 5 persons, 3 boats, 94.7ms
# video 1/1 (frame 2/96) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/barco_2.mp4: 640x384 5 persons, 3 boats, 80.1ms
# video 1/1 (frame 3/96) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/barco_2.mp4: 640x384 5 persons, 3 boats, 73.5ms
# ...

# %%
modelo.predict('carros - cópia.mp4', show = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/446) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/carros - cópia.mp4: 384x640 2 persons, 2 bicycles, 3 cars, 77.9ms
# video 1/1 (frame 2/446) /Users/arnaldomarianocarmona/Documents/Projetos_python/Testes_com_YOLO/carros - cópia.mp4: 384x640 2 persons, 2 bicycles, 4 cars, 87.1ms
# ...
